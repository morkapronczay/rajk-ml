# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.datasets import make_circles
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier, AdaBoostClassifier, ExtraTreesClassifier, GradientBoostingClassifier
from sklearn.metrics import f1_score

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def plot_scatters_of_fit(clf_fit):
    fig, ax = plt.subplots(1,3, figsize = (20, 8))
    sns.scatterplot(X_test[:, 0], X_test[:, 1],
                    y_test, ax = ax[0])
    sns.scatterplot(X_test[:, 0], X_test[:, 1],
                    clf_fit.predict(X_test), ax = ax[1])
    sns.scatterplot(X_test[:, 0], X_test[:, 1],
                    clf_fit.predict(X_test) == y_test, ax = ax[2])

    for axes, title_ in zip(ax, ['True classes', 'Predicted classes', 'Correct-incorrect classification']):
        axes.set_title(title_)
        axes.legend(loc = 1, prop = {'size': 15})
        
    return None

# %%
data = make_circles(n_samples=10000, noise=0.075, random_state=101)

# %%
sns.scatterplot(data[0][:, 0], data[0][:, 1], data[1])
plt.title('The Dataset')
plt.show()

# %%
X = data[0]
y = data[1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
sns.scatterplot(X_train[:, 0], X_train[:, 1], y_train)
plt.title('Train set')
# Out:
# Text(0.5, 1.0, 'Train set')

# %%
sns.scatterplot(X_test[:, 0], X_test[:, 1], y_test)
plt.title('Test set')
# Out:
# Text(0.5, 1.0, 'Test set')

# %% [markdown]
# ## SIMPLE DECISION TREE

# %%
base_tree = DecisionTreeClassifier(criterion='gini', max_depth=1, random_state=101)
base_tree_fit = base_tree.fit(X_train, y_train)

# %%
f1_score(y_train, base_tree_fit.predict(X_train))
# Out:
# 0.695817129849189

# %%
f1_score(y_test, base_tree_fit.predict(X_test))
# Out:
# 0.6965787997756591

# %%
plot_scatters_of_fit(base_tree_fit)

# %% [markdown]
# ## BAGGING

# %%
baggingclass = BaggingClassifier(base_tree, 100, random_state=101)
baggingclass_fit = baggingclass.fit(X_train, y_train)

# %%
f1_score(y_train, baggingclass_fit.predict(X_train))
# Out:
# 0.7287498730577842

# %%
f1_score(y_test, baggingclass_fit.predict(X_test))
# Out:
# 0.7342615012106538

# %%
plot_scatters_of_fit(baggingclass_fit)

# %% [markdown]
# ## RANDOM FOREST

# %%
# a special case for bagging
randomforest = RandomForestClassifier(100, criterion='gini', max_depth=1, random_state=101, bootstrap=True)
randomforest_fit = randomforest.fit(X_train, y_train)

# %%
f1_score(y_train, randomforest_fit.predict(X_train))
# Out:
# 0.7658643326039387

# %%
f1_score(y_test, randomforest_fit.predict(X_test))
# Out:
# 0.7736033975824893

# %%
plot_scatters_of_fit(randomforest_fit)

# %% [markdown]
# ### RANDOM FOREST AS BAGGING CLASSIFIER

# %%
random_forest_mod = RandomForestClassifier(100, criterion='gini', max_depth=1, random_state=101,
                                           max_features=1.0, bootstrap=True)

# %%
random_forest_modfit = random_forest_mod.fit(X_train, y_train)

# %%
f1_score(y_train, random_forest_modfit.predict(X_train))
# Out:
# 0.7287498730577842

# %%
f1_score(y_test, random_forest_modfit.predict(X_test))
# Out:
# 0.7342615012106538

# %%
f1_score(y_train, random_forest_modfit.predict(X_train)) == f1_score(y_train, baggingclass_fit.predict(X_train))
# Out:
# True

# %% [markdown]
# ### EXTRA TREES

# %%
extra_trees = ExtraTreesClassifier(100, criterion='gini', max_depth=1, random_state=101, max_features='auto', bootstrap=True)

# %%
extra_trees_fit = extra_trees.fit(X_train, y_train)

# %%
f1_score(y_train, extra_trees_fit.predict(X_train))
# Out:
# 0.8150061500615007

# %%
f1_score(y_test, extra_trees_fit.predict(X_test))
# Out:
# 0.8234432234432233

# %%
plot_scatters_of_fit(extra_trees_fit)

# %% [markdown]
# ## BOOSTING

# %%
adaboost = AdaBoostClassifier(base_tree, 100, random_state=101, learning_rate=1.)
adaboost_fit = adaboost.fit(X_train, y_train)

# %%
f1_score(y_train, adaboost_fit.predict(X_train))
# Out:
# 0.9007045061810448

# %%
f1_score(y_test, adaboost_fit.predict(X_test))
# Out:
# 0.9016459253311923

# %%
plot_scatters_of_fit(adaboost_fit)

# %% [markdown]
# ## GRADIENT BOOSTING

# %%
gbm = GradientBoostingClassifier(n_estimators=100, max_depth=1, random_state=101, max_features='auto')# estimator1000; subsample parameter .7 -> Stochastic Gradient Boosting
gbm_fit = gbm.fit(X_train, y_train)

# %%
f1_score(y_train, gbm_fit.predict(X_train))
# Out:
# 0.8125767624662245

# %%
f1_score(y_test, gbm_fit.predict(X_test))
# Out:
# 0.8243992606284659

# %%
plot_scatters_of_fit(gbm_fit)

# %% [markdown]
# ## EXTREME GRADIENT BOOSTING

# %%
import xgboost

# %%
# estimators 800
xgb = xgboost.XGBClassifier(max_depth=1, n_estimators=100, learning_rate=0.2)

# %%
xgb_fit = xgb.fit(X_train, y_train)

# %%
f1_score(y_train, xgb_fit.predict(X_train))
# Out:
# 0.9090909090909091

# %%
f1_score(y_test, xgb_fit.predict(X_test))
# Out:
# 0.9068471337579618

# %%
plot_scatters_of_fit(xgb_fit)
